# %% [markdown]
# # Project Title — Exploration
#
# **Goal:** [What are we exploring here?]
#
# **Key question:** [One sentence]
#
# **Status:** In progress

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# Publication-quality plot settings
mpl.rcParams.update({
    'font.family': 'serif',
    'font.size': 11,
    'axes.labelsize': 12,
    'legend.fontsize': 10,
    'figure.dpi': 150,
    'savefig.dpi': 300,
    'savefig.bbox': 'tight',
    'text.usetex': False,  # Set True if LaTeX installed
})

# %% [markdown]
# ## 1. Setup and parameters

# %%
# Physical parameters
params = {
    # Add parameters here
}

# %% [markdown]
# ## 2. Core simulation

# %% [markdown]
# ## 3. Results and figures

# %%
# Save figure for paper
# fig.savefig('../figures/fig1.pdf')
